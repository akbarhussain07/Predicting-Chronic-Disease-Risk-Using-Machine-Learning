# %%
import numpy as np

a = np.array([[1,2],
             [7,2]])

b = np.array([[4,3],
             [4,9]])

v_stack = np.vstack([a,b])
v_stack

#%%
# h_stack = np.hstack([a,b])
# h_stack
# Out:
# array([[1, 2],
#        [7, 2],
#        [4, 3],
#        [4, 9]])

# %%
import pandas as pd

ser = pd.Series([5,6,7,8])
print(ser)

np_array = np.array([0,1,2,'r',3])
print(np_array)
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64
# ['0' '1' '2' 'r' '3']

# %%
ser1=pd.Series([4,5,6,7,8],index=['a','b','c','d','e'])
ser1
# Out:
# a    4
# b    5
# c    6
# d    7
# e    8
# dtype: int64

# %%
print(ser1[:3])
# Out:
# a    4
# b    5
# c    6
# dtype: int64

# %%
# simple array
data = np.array(['g','e','e','k','s'])

ser = pd.Series(data)
print(ser)

print(ser[3:])
# Out:
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object
# 3    k
# 4    s
# dtype: object

# %%
ser = pd.Series(data,index=[10,11,12,13,14])

# print(ser)

print(ser[:3])
# #%%
# print(ser[3])
# #%%
# print(ser[14])
# Out:
# 10    g
# 11    e
# 12    e
# dtype: object

# %%
# print(ser[2:5])

print(ser.loc[11])
# Out:
# e

# %%
print(ser.iloc[1])
# Out:
# e

# %%
df = pd.read_csv(r"D:\MYFolder( Extra Effort)\DATASETS\user_behavior_dataset.csv") 
df.head() 
#%%   
ser = pd.Series(df['Device Model']) 
ser
#%%
# ser.head()
# Out:
# 0          Google Pixel 5
# 1               OnePlus 9
# 2            Xiaomi Mi 11
# 3          Google Pixel 5
# 4               iPhone 12
#               ...
# 695             iPhone 12
# 696          Xiaomi Mi 11
# 697        Google Pixel 5
# 698    Samsung Galaxy S21
# 699             OnePlus 9
# Name: Device Model, Length: 700, dtype: object

# %%
# creating a series
data = pd.Series([5, 2, 3,7], index=['a', 'b', 'c', 'd'])
# creating a series
data1 = pd.Series([1, 6, 4, 9], index=['a', 'b', 'd', 'e'])

# %%
# print(data, "\n\n", data1)
#%%
data2 = data.add(data1, fill_value=0)
data2
# Out:
# a     6.0
# b     8.0
# c     3.0
# d    11.0
# e     9.0
# dtype: float64

# %%
data + data1
# Out:
# a     6.0
# b     8.0
# c     NaN
# d    11.0
# e     NaN
# dtype: float64

# %%
print(data, "\n\n", data1)
data.add(data1, fill_value=1)
# print(df.dtypes)
# Out:
# a    5
# b    2
# c    3
# d    7
# dtype: int64
#
#  a    1
# b    6
# d    4
# e    9
# dtype: int64
# a     6.0
# b     8.0
# c     4.0
# d    11.0
# e    10.0
# dtype: float64

# %%
df["Data Usage (MB/day)"]= df["Data Usage (MB/day)"].astype(str)
print(df.dtypes)

# %%
# df["Data Usage (MB/day)"]= df["Data Usage (MB/day)"].astype(int)
# print(df.dtypes)
#%%
selected_df = df[ df["Data Usage (MB/day)"] < 1000 ].reset_index(drop=True)
selected_df
# Out:
#      User ID        Device Model Operating System  App Usage Time (min/day)  \
# 0          2           OnePlus 9          Android                       268
# 1          3        Xiaomi Mi 11          Android                       154
# 2          4      Google Pixel 5          Android                       239
# 3          5           iPhone 12              iOS                       187
# 4          6      Google Pixel 5          Android                        99
# ..       ...                 ...              ...                       ...
# 420      692           iPhone 12              iOS                       178
# 421      696           iPhone 12              iOS                        92
# 422      698      Google Pixel 5          Android                        99
# 423      699  Samsung Galaxy S21          Android                        62
# 424      700           OnePlus 9          Android                       212
#
# ...

# %%
my_list = df["Data Usage (MB/day)"].tolist()
print(my_list)
# Out:
# [1122, 944, 322, 871, 988, 564, 1054, 1702, 1053, 1301, 162, 641, 1099, 857, 779, 2025, 344, 985, 297, 2192, 302, 1553, 1372, 949, 748, 451, 1002, 1599, 1456, 1384, 889, 975, 917, 105, 1616, 153, 573, 2328, 1400, 1180, 708, 2323, 392, 429, 572, 1935, 1594, 323, 2262, 1997, 1417, 885, 393, 375, 2189, 111, 161, 2415, 1144, 1053, 1663, 1253, 128, 1717, 1091, 917, 912, 449, 1547, 284, 1090, 1701, 1082, 208, 125, 985, 122, 301, 138, 989, 1603, 549, 1133, 105, 695, 1352, 392, 276, 348, 1303, 307, 827, 284, 367, 1083, 1454, 1946, 1968, 293, 875, 136, 738, 565, 934, 360, 264, 596, 278, 711, 889, 459, 2344, 748, 404, 1324, 596, 281, 909, 124, 428, 1150, 2189, 2391, 1924, 714, 2378, 1321, 667, 465, 412, 1886, 1226, 458, 139, 285, 1856, 216, 868, 2076, 1796, 655, 1337, 429, 201, 2069, 974, 1026, 234, 823, 459, 1539, 207, 396, 1185, 102, 493, 136, 1062, 1493, 305, 262, 112, 1440, 139, 851, 1540, 2366, 158, 791, 1894, 524, 208, 578, 1406, 113, 629, 826, 972, 692, 2007, 571, 1079, 2416, 275, 1564,
# ...

# %%
num_series = pd.Series(np.random.randint(10, size=40))
num_series
num_series.value_counts()
# Out:
# 6    7
# 1    6
# 4    5
# 8    5
# 3    4
# 2    4
# 5    3
# 7    3
# 0    2
# 9    1
# Name: count, dtype: int64

# %%
this_series = pd.Series([0,1,2,np.nan,3,np.nan])
# print(this_series)
#%%
# this_series.fillna(0, inplace=True)
this_series
# Same 
this_series = this_series.fillna(0)
this_series
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# 3    0.0
# 4    3.0
# 5    0.0
# dtype: float64
